# %%
'''Extract transform Load'''
import requests 
import pandas as pd 
from sqlalchemy import create_engine

# %%
cookies = {
    'OPTIMIZELY_USER_ID': '0064c696-ca14-41c3-8cd6-1548fba6ada5',
    'client_guid_timestamp': 'ca282f8c-e1bf-4a1a-9cb5-9df8f8812bb7.1727472175148',
    '_gid': 'GA1.2.74011828.1727472179',
    '_sp_ses.8ca5': '*',
    '_fbp': 'fb.1.1727472185110.310214861220183031',
    '_li_dcdm_c': '.autolist.com',
    '_lc2_fpi': '48675baae283--01j8tnvbtz9mnq74fppe6wvgha',
    '_lc2_fpi_meta': '%7B%22w%22%3A1727472185184%7D',
    '_pubcid': '3e4aee08-03eb-44bd-9bc3-bac4cfe26bac',
    '_pubcid_cst': 'zix7LPQsHA%3D%3D',
    '_gcl_au': '1.1.448877401.1727472194',
    'pbjs-unifiedid': '%7B%22TDID%22%3A%2255df6f43-5b89-4ced-9df8-c54181597e2f%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222024-08-27T21%3A23%3A20%22%7D',
    'pbjs-unifiedid_cst': 'zix7LPQsHA%3D%3D',
    'panoramaId_expiry': '1728077001728',
    '_cc_id': 'fae83d56acc30ad5db8eec09f172f39e',
    'panoramaId': '5c5481fe9f91bd8a397bbd654bcf16d5393846a5c23f892bf3c9b5d4bb7d4679',
    '__gads': 'ID=62881434877c4098:T=1727472197:RT=1727472778:S=ALNI_Mb3VGC9DP4PnEo5GCT-FRL5FZwhNw',
    '__gpi': 'UID=00000f10082b5432:T=1727472197:RT=1727472778:S=ALNI_MbUiajH8WTp8ulHaRLAFqMv8R8v1A',
    '__eoi': 'ID=1a01ac6a9ce06510:T=1727472197:RT=1727472778:S=AA-AfjbA399qX6ISpOC3dSBBRXxn',
    'cto_bidid': 'ydFkeF9pRFZJJTJGZUklMkZYTEhMQ3o1R2hLJTJCSlJvM1ZiMTNtTWtsZHJtS29rZVltVFY2RjB6SUpzZjdLd0loWjY4TENIVE9MUVcxTFhBOGQ3UVU2T3l0Q0xrM2cxdzBnVnhHZnBnaDZsSlBkUVNwZHlFNCUzRA',
    '_uetsid': 'ad3b6d807d1611efbef7fd195589c642',
    '_uetvid': 'ad3bb1907d1611ef969ce5ac43262465',
    'cto_bundle': '',
    '_ga_KKZ1EQJKEV': 'GS1.1.1727472188.1.1.1727472942.0.0.0',
    '_ga': 'GA1.2.1140769343.1727472179',
    '_gat': '1',
    '_sp_id.8ca5': '26bb44e0-dc34-4234-ab19-f9f0f9589661.1727472180.1.1727472970.1727472180.ab33ca97-9679-495f-83fb-c890c3342485',
}

headers = {
    'accept': '*/*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7,ar;q=0.6',
    'cache-control': 'no-cache',
    # 'cookie': 'OPTIMIZELY_USER_ID=0064c696-ca14-41c3-8cd6-1548fba6ada5; client_guid_timestamp=ca282f8c-e1bf-4a1a-9cb5-9df8f8812bb7.1727472175148; _gid=GA1.2.74011828.1727472179; _sp_ses.8ca5=*; _fbp=fb.1.1727472185110.310214861220183031; _li_dcdm_c=.autolist.com; _lc2_fpi=48675baae283--01j8tnvbtz9mnq74fppe6wvgha; _lc2_fpi_meta=%7B%22w%22%3A1727472185184%7D; _pubcid=3e4aee08-03eb-44bd-9bc3-bac4cfe26bac; _pubcid_cst=zix7LPQsHA%3D%3D; _gcl_au=1.1.448877401.1727472194; pbjs-unifiedid=%7B%22TDID%22%3A%2255df6f43-5b89-4ced-9df8-c54181597e2f%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222024-08-27T21%3A23%3A20%22%7D; pbjs-unifiedid_cst=zix7LPQsHA%3D%3D; panoramaId_expiry=1728077001728; _cc_id=fae83d56acc30ad5db8eec09f172f39e; panoramaId=5c5481fe9f91bd8a397bbd654bcf16d5393846a5c23f892bf3c9b5d4bb7d4679; __gads=ID=62881434877c4098:T=1727472197:RT=1727472778:S=ALNI_Mb3VGC9DP4PnEo5GCT-FRL5FZwhNw; __gpi=UID=00000f10082b5432:T=1727472197:RT=1727472778:S=ALNI_MbUiajH8WTp8ulHaRLAFqMv8R8v1A; __eoi=ID=1a01ac6a9ce06510:T=1727472197:RT=1727472778:S=AA-AfjbA399qX6ISpOC3dSBBRXxn; cto_bidid=ydFkeF9pRFZJJTJGZUklMkZYTEhMQ3o1R2hLJTJCSlJvM1ZiMTNtTWtsZHJtS29rZVltVFY2RjB6SUpzZjdLd0loWjY4TENIVE9MUVcxTFhBOGQ3UVU2T3l0Q0xrM2cxdzBnVnhHZnBnaDZsSlBkUVNwZHlFNCUzRA; _uetsid=ad3b6d807d1611efbef7fd195589c642; _uetvid=ad3bb1907d1611ef969ce5ac43262465; cto_bundle=; _ga_KKZ1EQJKEV=GS1.1.1727472188.1.1.1727472942.0.0.0; _ga=GA1.2.1140769343.1727472179; _gat=1; _sp_id.8ca5=26bb44e0-dc34-4234-ab19-f9f0f9589661.1727472180.1.1727472970.1727472180.ab33ca97-9679-495f-83fb-c890c3342485',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://www.autolist.com/listings',
    'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
    'x-kl-ajax-request': 'Ajax_Request',
}

params = {
    'ads': 'true',
    'include_total_price_change': 'true',
    'include_time_on_market': 'true',
    'include_relative_price_difference': 'true',
    'latitude': '40.7714367',
    'limit': '20',
    'longitude': '-84.6155134',
    'make': 'Toyota',
    'page': '1',
    'radius': '100',
    'zip': '',
}

response = requests.get('https://www.autolist.com/api/v2/search', params=params, cookies=cookies, headers=headers)
print(response) # we will get 200 which means we can get the wanted data.
# Out:
# <Response [200]>

# %%
results = response.json()["records"]
print(results[0]) # This contains the details of the first car
# Out:
# {'id': 295949134, 'accepts_click_off': True, 'accepts_leads': True, 'accepts_leads_and_click_off': True, 'always_ask_for_zip': False, 'available_nationwide': False, 'backup_camera': True, 'bed': None, 'bluetooth': True, 'body_style': 'sedan', 'body_type': 'sedan', 'cabin': None, 'categories': ['fuel_efficient'], 'city': 'Fort Wayne', 'city_mpg': 27, 'clickoff_url': 'https://www.rohrman.com/catcher.esl?vin=4T1K61AK8RU238449&utm_source=autolist&utm_medium=referral&utm_campaign=vdp_deep_link', 'combined_mpg': 31, 'condition': 'used', 'cpl_value': 15, 'created_at': '2024-08-14T19:04:14.844Z', 'dealer_group_uuid': '3a0649af-70a9-4973-92f9-e08d8c5b4e18', 'dealer_name': 'Fort Wayne Toyota', 'distance_from_origin': 37, 'door_count': 4, 'driveline': 'FWD', 'eligible_for_financing': False, 'email_opt_default': True, 'engine_cylinders': 4, 'entertainment': False, 'experience': 'local', 'finance_dealer_id': None, 'financing_experience': 'none', 'fuel_type': 'gasoline', 'green_engine': False, 'ha
# ...

# %%
print(results[0].keys()) # This will give us the keys of the dictionary
# Out:
# dict_keys(['id', 'accepts_click_off', 'accepts_leads', 'accepts_leads_and_click_off', 'always_ask_for_zip', 'available_nationwide', 'backup_camera', 'bed', 'bluetooth', 'body_style', 'body_type', 'cabin', 'categories', 'city', 'city_mpg', 'clickoff_url', 'combined_mpg', 'condition', 'cpl_value', 'created_at', 'dealer_group_uuid', 'dealer_name', 'distance_from_origin', 'door_count', 'driveline', 'eligible_for_financing', 'email_opt_default', 'engine_cylinders', 'entertainment', 'experience', 'finance_dealer_id', 'financing_experience', 'fuel_type', 'green_engine', 'handicap_accessible', 'has_photos', 'heated_seats', 'hwy_mpg', 'ipod_aux_input', 'is_hot', 'lane_departure_warning_system', 'lat', 'leather', 'lon', 'make_and_model', 'make_name', 'max_distance', 'mileage', 'model_id', 'model_name', 'national_backfill', 'national_backfill_priority', 'navigation', 'normalized_color_exterior', 'normalized_color_interior', 'one_owner', 'open_in_new_window', 'partner_type', 'phone', 'photo_urls
# ...

# %%
# We will extract the data from the dictionary and store it in a list
model=[]
price=[]
dealer=[]
mileage=[]
city=[]
cylinder=[]
timeOnMarket=[]

for result in results:
    model.append(result['make_and_model'])
    mileage.append(result['mileage'])
    city.append(result['city'])
    price.append(result['price'])
    cylinder.append(result['engine_cylinders'])
    dealer.append(result['dealer_name'])
    timeOnMarket.append(result['time_on_market'])

df = pd.DataFrame({
    
    'model':model,
    'price':price,
    'mileage':mileage,
    'cylinder':cylinder,
    'daysOnMarket': timeOnMarket,
    'city': city,
    'dealer': dealer
})

df.head(10)
# Out:
#                 model  price  mileage  cylinder  daysOnMarket        city  \
# 0        toyota_camry  33300    17991         4            44  Fort Wayne
# 1       toyota_tundra  59180        2         6            21  Fort Wayne
# 2  toyota_rav4 hybrid  38100    13442         4             8  Fort Wayne
# 3         toyota_rav4  38000     3993         4             0    Ft Wayne
# 4         toyota_rav4  32800    35400         4            33  Fort Wayne
# 5         toyota_rav4  34900    12202         4            36  Fort Wayne
# 6     toyota_4_runner  27487    57843         6            66        Peru
# 7       toyota_tacoma  31300    50949         6            14  Fort Wayne
# 8  toyota_rav4 hybrid  36495    23412         4            14    Delaware
# 9  toyota_rav4 hybrid  37000    22577         4            20  Fort Wayne
#
#                              dealer
# 0                 Fort Wayne Toyota
# 1                 Fort Wayne Toyota
# 2                 Fort Wayne Toyota
# ...

# %%
#After showing an example of extracting one page in the website,let's extract from 9 pages to show that we can extract data from multiple pages.
model=[]
price=[]
dealer=[]
mileage=[]
city=[]
cylinder=[]
timeOnMarket=[]
transmission =[]

cookies = {
    '_pbjs_userid_consent_data': '3524755945110770',
    '_pubcid': '236bc955-0cb4-41c3-9124-d6a9f2ecc8d2',
    '_gcl_au': '1.1.275871171.1698044446',
    'pbjs-unifiedid': '%7B%22TDID%22%3A%2242ade502-7af9-4db6-9bd8-1d81974beb94%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222023-09-23T07%3A00%3A52%22%7D',
    '_cc_id': 'ebca25b2be886cb76af2420a89f6f76f',
    '_fbp': 'fb.1.1698044458044.1058932602',
    'ec': 'eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzExOC4wLjAuMCBTYWZhcmkvNTM3LjM2In0=',
    'client_guid_timestamp': '574a80fa-9c34-4ca5-8205-2d6e9351fae8.1698044442569',
    '_gid': 'GA1.2.1639785694.1698406454',
    '_sp_ses.8ca5': '*',
    'panoramaId_expiry': '1698492861840',
    'panoramaId': '6692080e610caad7f5fd03b398c9a9fb927ac80a2e4c5a92c2319d2739214d72',
    '_uetsid': 'c3535db074bc11ee95a83bd1d749982c',
    '_uetvid': 'e4a91240717111eebe1bcbfc83a90a51',
    'cto_bidid': '6jraU19uT3pwdWZZd2FMSlJDNUJXWmxLbWc2YnMlMkZKc0t4MkE2Z013N0FsTG9iWkVPcVdDOTRqZEpsa05kbHEzcSUyRmolMkJ6Y3VadHlvS0hvZ3ZsVWRsS0JrSjgyQ3N6WHhlbVVXVGdMUTNkVERpNTdBcyUzRA',
    '__gads': 'ID=2b41342773a80bf6:T=1698044453:RT=1698406816:S=ALNI_Mb_F5UDlmnb1xwKwDHcJ94uZhcF6w',
    '__gpi': 'UID=00000cc00631fd72:T=1698044453:RT=1698406816:S=ALNI_Mb72JfJm5nrbkfE-gqgNhbzkQPdhw',
    '_ga': 'GA1.1.856422917.1698044445',
    'cto_bundle': '',
    '_ga_KKZ1EQJKEV': 'GS1.1.1698406467.4.1.1698407030.0.0.0',
    '_sp_id.8ca5': '73a7d012-4ea8-4a60-bc7f-ce7dabac5759.1698044447.4.1698407085.1698132957.bf070983-70a3-403c-b510-1571f1572fda',
}

headers = {
    'authority': 'www.autolist.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,fr-FR;q=0.8,fr;q=0.7',
    'cache-control': 'no-cache',
    # 'cookie': '_pbjs_userid_consent_data=3524755945110770; _pubcid=236bc955-0cb4-41c3-9124-d6a9f2ecc8d2; _gcl_au=1.1.275871171.1698044446; pbjs-unifiedid=%7B%22TDID%22%3A%2242ade502-7af9-4db6-9bd8-1d81974beb94%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222023-09-23T07%3A00%3A52%22%7D; _cc_id=ebca25b2be886cb76af2420a89f6f76f; _fbp=fb.1.1698044458044.1058932602; ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzExOC4wLjAuMCBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=574a80fa-9c34-4ca5-8205-2d6e9351fae8.1698044442569; _gid=GA1.2.1639785694.1698406454; _sp_ses.8ca5=*; panoramaId_expiry=1698492861840; panoramaId=6692080e610caad7f5fd03b398c9a9fb927ac80a2e4c5a92c2319d2739214d72; _uetsid=c3535db074bc11ee95a83bd1d749982c; _uetvid=e4a91240717111eebe1bcbfc83a90a51; cto_bidid=6jraU19uT3pwdWZZd2FMSlJDNUJXWmxLbWc2YnMlMkZKc0t4MkE2Z013N0FsTG9iWkVPcVdDOTRqZEpsa05kbHEzcSUyRmolMkJ6Y3VadHlvS0hvZ3ZsVWRsS0JrSjgyQ3N6WHhlbVVXVGdMUTNkVERpNTdBcyUzRA; __gads=ID=2b41342773a80bf6:T=1698044453:RT=1698406816:S=ALNI_Mb_F5UDlmnb1xwKwDHcJ94uZhcF6w; __gpi=UID=00000cc00631fd72:T=1698044453:RT=1698406816:S=ALNI_Mb72JfJm5nrbkfE-gqgNhbzkQPdhw; _ga=GA1.1.856422917.1698044445; cto_bundle=; _ga_KKZ1EQJKEV=GS1.1.1698406467.4.1.1698407030.0.0.0; _sp_id.8ca5=73a7d012-4ea8-4a60-bc7f-ce7dabac5759.1698044447.4.1698407085.1698132957.bf070983-70a3-403c-b510-1571f1572fda',
    'pragma': 'no-cache',
    'referer': 'https://www.autolist.com/listings',
    'sec-ch-ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36',
}

for i in range(1, 10):
    
    params = {
        'include_total_price_change': 'true',
        'include_time_on_market': 'true',
        'include_relative_price_difference': 'true',
        'latitude': '41.5575349',
        'limit': '20',
        'longitude': '-89.46092759999999',
        'make': 'Toyota',
        'page': str(i),
        'radius': '100',
    }

    response = requests.get('https://www.autolist.com/api/v2/search', params=params, cookies=cookies, headers=headers)
    results = response.json()['records']
    
    for result in results:
        model.append(result['make_and_model'])
        mileage.append(result['mileage'])
        city.append(result['city'])
        price.append(result['price'])
        cylinder.append(result['engine_cylinders'])
        dealer.append(result['dealer_name'])
        timeOnMarket.append(result['time_on_market'])
        transmission.append(result['transmission'])
        
    
    
df_all = pd.DataFrame({
    
    'model': model,
    'price': price,
    'mileage':mileage,
    'cylinder':cylinder,
    'daysOnMarket': timeOnMarket,
    'city': city,
    'dealer':dealer,
    'transmission': transmission
})

df_all.shape
# Out:
# (180, 8)

# %%
engine =  create_engine('mysql+pymysql://root:root@localhost/voiture')
df_all.to_sql('toyota',con=engine,if_exists='replace',index=False)
# Out:
# 180
